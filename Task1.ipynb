# %% [markdown]
# <a href="https://colab.research.google.com/github/hosamkefah/Data-Analysis-with-Python/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Employee Sample Data - A.xlsx")

# %%
df.head(10)
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity   Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black  55.0 2016-04-08       141604.0
# 1           Manufacturing    Male      Asian  59.0 1997-11-29        99975.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      998 non-null    object
#  2   Job Title      999 non-null    object
#  3   Department     998 non-null    object
#  4   Business Unit  1000 non-null   object
#  5   Gender         999 non-null    object
#  6   Ethnicity      993 non-null    object
#  7   Age            994 non-null    float64
#  8   Hire Date      993 non-null    datetime64[ns]
#  9   Annual Salary  989 non-null    float64
#  10  Bonus %        992 non-null    float64
#  11  Country        998 non-null    object
#  12  City           998 non-null    object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), object(9)
# memory usage: 109.5+ KB

# %%
df.size
# Out:
# 14000

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.describe()
# Out:
#               Age                      Hire Date  Annual Salary     Bonus %  \
# count  994.000000                            993      989.00000  992.000000
# mean    44.369215  2012-04-17 22:56:11.601208576   113372.62184    0.088972
# min     25.000000            1992-01-09 00:00:00    40063.00000    0.000000
# 25%     35.000000            2007-02-24 00:00:00    71234.00000    0.000000
# 50%     45.000000            2014-02-20 00:00:00    96567.00000    0.000000
# 75%     54.000000            2018-06-25 00:00:00   151027.00000    0.150000
# max     65.000000            2021-12-26 00:00:00   258498.00000    0.400000
# std     11.248162                            NaN    53729.04678    0.118135
#
#                            Exit Date
# count                             85
# mean   2016-11-02 18:04:14.117647104
# min              1994-12-18 00:00:00
# 25%              2014-12-25 00:00:00
# 50%              2019-05-23 00:00:00
# 75%              2021-04-09 00:00:00
# ...

# %%
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity   Age  Hire Date  \
# 0    Research & Development  Female      Black  55.0 2016-04-08
# ...

# %%
df.isnull().sum()
# Out:
# EEID               0
# Full Name          2
# Job Title          1
# Department         2
# Business Unit      0
# Gender             1
# Ethnicity          7
# Age                6
# Hire Date          7
# Annual Salary     11
# Bonus %            8
# Country            2
# City               2
# Exit Date        915
# dtype: int64

# %%
df_c = df.copy()

# %%
df_c['EEID'] = df_c['EEID'].astype(str)

# %%
df_c = df_c.dropna(subset = ['Full Name']) #, 'Department', 'Job Title'

# %%
df_c['Age'] = df_c['Age'].fillna(df_c['Age'].mean())

# %%
df_c.isna().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          1
# Department         2
# Business Unit      0
# Gender             1
# Ethnicity          7
# Age                0
# Hire Date          7
# Annual Salary     11
# Bonus %            8
# Country            2
# City               2
# Exit Date        913
# dtype: int64

# %%
df_c['Annual Salary'] = df_c['Annual Salary'].fillna(df_c['Annual Salary'].median())

# %%
df_c.isna().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          1
# Department         2
# Business Unit      0
# Gender             1
# Ethnicity          7
# Age                0
# Hire Date          7
# Annual Salary      0
# Bonus %            8
# Country            2
# City               2
# Exit Date        913
# dtype: int64

# %%
df_c[df_c['Country'].isna()]
# Out:
#        EEID      Full Name   Job Title       Department  Business Unit Gender  \
# 115  E02017  Connor Joseph    Director  Human Resources      Corporate   Male
# 130  E03131   Ezekiel Reed  Sr. Manger               IT  Manufacturing   Male
#
#      Ethnicity   Age Hire Date  Annual Salary  Bonus % Country City  Exit Date
# 115  Caucasian  50.0       NaT        96567.0      NaN     NaN  NaN        NaT
# 130  Caucasian  37.0       NaT        96567.0      NaN     NaN  NaN 2021-05-01

# %%
df_c['Ethnicity'] = df_c['Ethnicity'].fillna(df_c['Ethnicity'].mode()[0])

# %%
most_frequent_combo = df_c[['City', 'Country']].mode()
most_frequent_city = most_frequent_combo['City'][0]
most_frequent_country = most_frequent_combo['Country'][0]

df_c.loc[df_c['City'].isna() & df_c['Country'].isna(), 'City'] = most_frequent_city
df_c.loc[df_c['Country'].isna(), 'Country'] = most_frequent_country

# %%
#df_c['Country'] = df_c['Country'].fillna(df_c['Country'].mode()[0])
df_c[df_c['Country'].isna()]
# Out:
# Empty DataFrame
# Columns: [EEID, Full Name, Job Title, Department, Business Unit, Gender, Ethnicity, Age, Hire Date, Annual Salary, Bonus %, Country, City, Exit Date]
# Index: []

# %%
#df_c['City'] = df_c['City'].fillna(df_c['City'].mode()[0])

# %%
df_c['Bonus %'] = df_c['Bonus %'].fillna(df_c['Bonus %'].median())

# %%
df_c.isna().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          1
# Department         2
# Business Unit      0
# Gender             1
# Ethnicity          0
# Age                0
# Hire Date          7
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        913
# dtype: int64

# %%
df_c['Hire Date'] = df_c['Hire Date'].fillna(df_c['Hire Date'].mode()[0])

# %%
df_c.isna().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          1
# Department         2
# Business Unit      0
# Gender             1
# Ethnicity          0
# Age                0
# Hire Date          0
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        913
# dtype: int64

# %%
df_c['Job Title'] = df_c['Job Title'].fillna('Unknown')
df_c['Department'] = df_c['Department'].fillna('Unknown')
df_c['Gender'] = df_c['Gender'].fillna('Unknown')

# %%
#df_c['Exit Date'] = df_c['Exit Date'].fillna(0000-00-00)

# %%
df_c.isna().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          0
# Department         0
# Business Unit      0
# Gender             0
# Ethnicity          0
# Age                0
# Hire Date          0
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        913
# dtype: int64

# %%
df_c['Still Working'] = df_c['Exit Date'].isnull()
df_c['Still Working'] = df_c['Still Working'].replace(False, 'NO')
df_c['Still Working'] = df_c['Still Working'].replace(True, 'YES')
df_c.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity   Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black  55.0 2016-04-08       141604.0
# 1           Manufacturing    Male      Asian  59.0 1997-11-29        99975.0
# 2     Speciality Products  Female  Caucasian  50.0 2006-10-26       163099.0
# 3           Manufacturing  Female  Caucasian  26.0 2019-09-27        84913.0
# 4           Manufacturing    Male      Asian  55.0 1995-11-20        95409.0
#
#    Bonus %        Country       City  Exit Date Still Working
# ...

# %%
df_c[df_c['Age'] < 40]
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 6    E01550      Ruby Barnes                   Manager          IT
# 7    E04332      Luke Martin                   Analyst     Finance
# 8    E04533    Easton Bailey                   Manager  Accounting
# 9    E03838  Madeline Walker               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 990  E01578     Anthony Hong                Sr. Manger          IT
# 992  E03058    Robert Wright       Technical Architect          IT
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
#
#               Business Unit  Gender  Ethnicity   Age  Hire Date  \
# 3             Manufacturing  Female  Caucasian  26.0 2019-09-27
# ...

# %%
df_c.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity   Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black  55.0 2016-04-08       141604.0
# 1           Manufacturing    Male      Asian  59.0 1997-11-29        99975.0
# 2     Speciality Products  Female  Caucasian  50.0 2006-10-26       163099.0
# 3           Manufacturing  Female  Caucasian  26.0 2019-09-27        84913.0
# 4           Manufacturing    Male      Asian  55.0 1995-11-20        95409.0
#
#    Bonus %        Country       City  Exit Date Still Working
# ...

# %%
df_c.loc[0, 'Full Name'] = 'Hussam Alsayahien'
df_c.loc[1, 'Department'] = 'Finance'
df_c.loc[2, 'Full Name'] = 'Lama Alsabahien'
df_c.loc[3, 'Age'] = 40
df_c.loc[4, 'Gender'] = 'Female'

# %%
df_c.head()
# Out:
#      EEID          Full Name                 Job Title Department  \
# 0  E02387  Hussam Alsayahien                Sr. Manger         IT
# 1  E04105      Theodore Dinh       Technical Architect    Finance
# 2  E02572    Lama Alsabahien                  Director    Finance
# 3  E02832    Penelope Jordan  Computer Systems Manager         IT
# 4  E01639          Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity   Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black  55.0 2016-04-08       141604.0
# 1           Manufacturing    Male      Asian  59.0 1997-11-29        99975.0
# 2     Speciality Products  Female  Caucasian  50.0 2006-10-26       163099.0
# 3           Manufacturing  Female  Caucasian  40.0 2019-09-27        84913.0
# 4           Manufacturing  Female      Asian  55.0 1995-11-20        95409.0
#
#    Bonus %        Country       City  Exit Date Still Working
# ...

# %%
highest_salary = df_c[df_c['Annual Salary'] == df_c['Annual Salary'].max()]
print(f"{highest_salary}")
# Out:
#        EEID     Full Name       Job Title Department  Business Unit  Gender  \
# 989  E04354  Raelynn Rios  Vice President      Sales  Manufacturing  Female
#
#     Ethnicity   Age  Hire Date  Annual Salary  Bonus %        Country  \
# 989    Latino  43.0 2016-08-21       258498.0     0.35  United States
#
#          City Exit Date Still Working
# 989  Columbus       NaT           YES

# %%
#dept_group = df_c.groupby('Department')[['Age', 'Annual Salary']].mean()
dept_group = df_c.groupby('Department').agg({
    'Age' : 'mean',
    'Annual Salary': 'mean'
})

print(dept_group)
# Out:
#                        Age  Annual Salary
# Department
# Accounting       43.656250  123146.947917
# Engineering      45.747605  108439.974522
# Finance          45.317140  122796.173554
# Human Resources  44.443548  117907.088710
# IT               44.328244   97982.176471
# Marketing        43.216667  129663.033333
# Sales            43.609814  111120.635714
# Unknown          45.000000   66902.500000

# %%
group = df_c.groupby(['Department', 'Ethnicity']).agg({
    'Age' : ['max', 'min'],
    'Annual Salary': 'median'
})
print(group)
# Out:
#                             Age       Annual Salary
#                             max   min        median
# Department      Ethnicity
# Accounting      Asian      64.0  25.0      114893.0
#                 Black      51.0  30.0       91853.0
#                 Caucasian  62.0  26.0      121159.5
#                 Latino     62.0  26.0       92317.0
# Engineering     Asian      65.0  25.0       91782.0
#                 Black      56.0  27.0       74412.0
#                 Caucasian  64.0  25.0       95639.0
#                 Latino     64.0  27.0       96818.0
# Finance         Asian      64.0  25.0      122890.0
#                 Black      65.0  25.0      131652.0
#                 Caucasian  64.0  25.0      102847.0
#                 Latino     65.0  25.0      124553.0
# Human Resources Asian      64.0  25.0      125871.5
#                 Black      55.0  25.0      142318.0
#                 Caucasian  64.0  26.0      100364.5
#                 Latino     65.0  29.0      101985.0
# ...

# %%
df_c.groupby('Department').agg({
    'Annual Salary': lambda x: x.max() - x.min()  # salary range
})
# Out:
#                  Annual Salary
# Department
# Accounting            213377.0
# Engineering           195414.0
# Finance               214033.0
# Human Resources       209225.0
# IT                    216498.0
# Marketing             216442.0
# Sales                 217069.0
# Unknown                15671.0

# %%
# Flatten MultiIndex columns
group.columns = ['Max Age', 'Min Age', 'Median Salary']

# %%
group
# Out:
#                            Max Age  Min Age  Median Salary
# Department      Ethnicity
# Accounting      Asian         64.0     25.0       114893.0
#                 Black         51.0     30.0        91853.0
#                 Caucasian     62.0     26.0       121159.5
#                 Latino        62.0     26.0        92317.0
# Engineering     Asian         65.0     25.0        91782.0
#                 Black         56.0     27.0        74412.0
#                 Caucasian     64.0     25.0        95639.0
#                 Latino        64.0     27.0        96818.0
# Finance         Asian         64.0     25.0       122890.0
#                 Black         65.0     25.0       131652.0
#                 Caucasian     64.0     25.0       102847.0
#                 Latino        65.0     25.0       124553.0
# Human Resources Asian         64.0     25.0       125871.5
#                 Black         55.0     25.0       142318.0
# ...

# %%
group = group.reset_index()

# %%
group
# Out:
#          Department  Ethnicity  Max Age  Min Age  Median Salary
# 0        Accounting      Asian     64.0     25.0       114893.0
# 1        Accounting      Black     51.0     30.0        91853.0
# 2        Accounting  Caucasian     62.0     26.0       121159.5
# 3        Accounting     Latino     62.0     26.0        92317.0
# 4       Engineering      Asian     65.0     25.0        91782.0
# 5       Engineering      Black     56.0     27.0        74412.0
# 6       Engineering  Caucasian     64.0     25.0        95639.0
# 7       Engineering     Latino     64.0     27.0        96818.0
# 8           Finance      Asian     64.0     25.0       122890.0
# 9           Finance      Black     65.0     25.0       131652.0
# 10          Finance  Caucasian     64.0     25.0       102847.0
# 11          Finance     Latino     65.0     25.0       124553.0
# 12  Human Resources      Asian     64.0     25.0       125871.5
# 13  Human Resources      Black     55.0     25.0       142318.0
# ...

# %%
with pd.ExcelWriter("employee_summary1.xlsx") as writer:
    df_c.to_excel(writer, sheet_name="Cleaned Data", index=False)
    group.to_excel(writer, sheet_name="Grouped Summary", index=False)
